# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bfc4e5e7-ae27-4813-87f3-a17a6502edc2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bfc4e5e7-ae27-4813-87f3-a17a6502edc2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('perrin-freres-monthly-champagne-.csv')

# %%
df.head()
# Out:
#      Month  Perrin Freres monthly champagne sales millions ?64-?72
# 0  1964-01                                             2815.0
# 1  1964-02                                             2672.0
# 2  1964-03                                             2755.0
# 3  1964-04                                             2721.0
# 4  1964-05                                             2946.0

# %%
df.tail()
# Out:
#                                                  Month  \
# 102                                            1972-07
# 103                                            1972-08
# 104                                            1972-09
# 105                                                NaN
# 106  Perrin Freres monthly champagne sales millions...
#
#      Perrin Freres monthly champagne sales millions ?64-?72
# 102                                             4298.0
# 103                                             1413.0
# 104                                             5877.0
# 105                                                NaN
# 106                                                NaN

# %%
df.columns=['Month', 'Sales']
df.head()
# Out:
#      Month   Sales
# 0  1964-01  2815.0
# 1  1964-02  2672.0
# 2  1964-03  2755.0
# 3  1964-04  2721.0
# 4  1964-05  2946.0

# %%
df.drop(106,axis=0,inplace=True)

# %%
df.drop(105,axis=0,inplace=True)

# %%
df['Month']=pd.to_datetime(df['Month'])

# %%
df.head()
# Out:
#        Month   Sales
# 0 1964-01-01  2815.0
# 1 1964-02-01  2672.0
# 2 1964-03-01  2755.0
# 3 1964-04-01  2721.0
# 4 1964-05-01  2946.0

# %%
df.set_index('Month',inplace=True)

# %%
df.head()
# Out:
#              Sales
# Month
# 1964-01-01  2815.0
# 1964-02-01  2672.0
# 1964-03-01  2755.0
# 1964-04-01  2721.0
# 1964-05-01  2946.0

# %%
df.describe()
# Out:
#               Sales
# count    105.000000
# mean    4761.152381
# std     2553.502601
# min     1413.000000
# 25%     3113.000000
# 50%     4217.000000
# 75%     5221.000000
# max    13916.000000

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result=adfuller(df['Sales'])

# %%
#null hypothesis: time series is non-stationary
#alternate hypothesis: time series is stationary


def adfuller_test(sales):
  result = adfuller(sales)
  labels = ['ADF test statistics', 'p-value','#lag used','No. of observations used']
  for value,label in zip(result,labels):
    print(label+ ":"+str(value))
    if result[1]<=0.05:
      print('Reject null hypothesis')
    else:
      print('Fail to reject null hypothesis')

# %%
adfuller_test(df['Sales'])
# Out:
# ADF test statistics:-1.8335930563276215
# Fail to reject null hypothesis
# p-value:0.36391577166024586
# Fail to reject null hypothesis
# #lag used:11
# Fail to reject null hypothesis
# No. of observations used:93
# Fail to reject null hypothesis

# %%
df['sales_diff']=df['Sales']-df['Sales'].shift(1)

# %%
df['yearly_diff']=df['Sales']-df['Sales'].shift(12)

# %%
df.head(14)
# Out:
#              Sales  sales_diff  yearly_diff
# Month
# 1964-01-01  2815.0         NaN          NaN
# 1964-02-01  2672.0      -143.0          NaN
# 1964-03-01  2755.0        83.0          NaN
# 1964-04-01  2721.0       -34.0          NaN
# 1964-05-01  2946.0       225.0          NaN
# 1964-06-01  3036.0        90.0          NaN
# 1964-07-01  2282.0      -754.0          NaN
# 1964-08-01  2212.0       -70.0          NaN
# 1964-09-01  2922.0       710.0          NaN
# 1964-10-01  4301.0      1379.0          NaN
# 1964-11-01  5764.0      1463.0          NaN
# 1964-12-01  7312.0      1548.0          NaN
# 1965-01-01  2541.0     -4771.0       -274.0
# 1965-02-01  2475.0       -66.0       -197.0

# %%
adfuller_test(df['yearly_diff'].dropna())
# Out:
# ADF test statistics:-7.626619157213166
# Reject null hypothesis
# p-value:2.0605796968136632e-11
# Reject null hypothesis
# #lag used:0
# Reject null hypothesis
# No. of observations used:92
# Reject null hypothesis

# %%
df['yearly_diff'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Sales'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['yearly_diff'].iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['yearly_diff'].iloc[13:],lags=40,ax=ax2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model = ARIMA(df['Sales'], order=(1, 1, 1))
model_fit = model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Sales   No. Observations:                  105
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -952.814
# Date:                Fri, 10 Jan 2025   AIC                           1911.627
# Time:                        08:17:58   BIC                           1919.560
# Sample:                    01-01-1964   HQIC                          1914.841
#                          - 09-01-1972
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4545      0.114      4.001      0.000       0.232       0.677
# ma.L1         -0.9667      0.056    -17.329      0.000      -1.076      -0.857
# sigma2      5.226e+06   6.17e+05      8.472      0.000    4.02e+06    6.44e+06
# ...

# %%
df['forecast']=model_fit.predict(start=90,end=103,dynamic=True)
df[['Sales','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Month'>

# %%
model2=sm.tsa.statespace.SARIMAX(df['Sales'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model2.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
df['forecast']=results.predict(start=90,end=103,dynamic=True)
df[['Sales','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Month'>

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[df.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            Sales sales_diff yearly_diff forecast
# 1974-04-01   NaN        NaN         NaN      NaN
# 1974-05-01   NaN        NaN         NaN      NaN
# 1974-06-01   NaN        NaN         NaN      NaN
# 1974-07-01   NaN        NaN         NaN      NaN
# 1974-08-01   NaN        NaN         NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])
# Out:
# <ipython-input-52-4cc8c9eff41a>:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   future_df=pd.concat([df,future_datest_df])

# %%
future_df['forecast'] = results.predict(start = 104, end = 120, dynamic= True)
future_df[['Sales', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >
